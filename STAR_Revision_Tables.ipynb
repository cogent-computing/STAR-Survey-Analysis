# %% [markdown]
# # Multinomial Logistic Regression Model
#
# To be run after data cleaning process

# %%
#Imports

import numpy as np
import pandas as pd
import warnings
import os
warnings.filterwarnings("ignore")

import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import norm
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import roc_auc_score as AUC, accuracy_score as Acc
from sklearn.model_selection import KFold, LeaveOneOut, cross_validate as CV
from sklearn.model_selection import GridSearchCV
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression as LR
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import MNLogit
from itertools import chain, combinations

# %%
data = pd.read_csv('ml_preppred_surve.csv')
data.shape
# Out:
# (165, 17)

# %%
data = data.drop(columns = ['Unnamed: 0', 'Which is the main one?'])
data['Resident:  Permanent '] = data['Resident:  Permanent '].fillna(value = 0)
data = data.dropna()
data.shape
# Out:
# (131, 15)

# %%
data['Civil state'][(data['Civil state'] == 2) | (data['Civil state'] == 3)] = 100
data['Civil state'][data['Civil state'] != 100] = 200
data['Civil state'] = data['Civil state']/100
data.shape
# Out:
# (131, 15)

# %%
data['House'][data['House'] == 5] = 100
data['House'][data['House'] != 100] = 200
data['House'] = data['House']/100
data.shape
# Out:
# (131, 15)

# %%
data.head()
# Out:
#    Community name  Where do you normally cook?   \
# 2               1                           3.0
# 3               1                           3.0
# 5               1                           3.0
# 6               1                           3.0
# 7               1                           3.0
#
#    What is the family's monthly income? (Brazil´s Minimum Wage R$937.00)  \
# 2                                                2.0
# 3                                                2.0
# 5                                                3.0
# 6                                                3.0
# 7                                                3.0
#
#    Resident:  Permanent   Gender (M or F)  Age  Civil state  Education  House  \
# 2                    1.0              2.0    3          2.0        3.0    1.0
# 3                    1.0              1.0    2          1.0        4.0    1.0
# 5                    1.0              2.0    1          1.0        3.0    1.0
# 6                    1.0              1.0    1          2.0        3.0    1.0
# 7                    1.0              1.0    4          2.0        6.0    1.0
#
#    How many meals a day?   . How many people eat at home daily?   \
# 2                     4.0                                    2.0
# 3                     3.0                                    4.0
# 5                     3.0                                    3.0
# 6                     3.0                                    4.0
# 7                     4.0                                    4.0
#
#    How many contribute to the family's monthly income?   FuelChoice  \
# 2                                                2.0              2
# 3                                                1.0              2
# 5                                                1.0              4
# 6                                                1.0              4
# 7                                                2.0              4
#
#    Number_Men  Number_Women
# 2           1             1
# 3           2             2
# 5           1             2
# 6           2             2
# 7           3             1

# %%
y = data['FuelChoice']
# Switching categories 1 and 3, so that LPG- Charcoal is the reference category
y[y == 1] = -1
y[y == 3] = 1
y[y == -1] = 3
y.unique()
# Out:
# array([2, 4, 1, 3], dtype=int64)

# %%
data.columns
# Out:
# Index(['Community name', 'Where do you normally cook? ',
#        'What is the family's monthly income? (Brazil´s Minimum Wage R$937.00)',
#        'Resident:  Permanent ', 'Gender (M or F)', 'Age', 'Civil state',
#        'Education', 'House', 'How many meals a day? ',
#        '. How many people eat at home daily? ',
#        'How many contribute to the family's monthly income? ', 'FuelChoice',
#        'Number_Men', 'Number_Women'],
#       dtype='object')

# %%
#X = data.drop(columns = ['FuelChoice', 'How many contribute to the family\'s monthly income? '])
X = data.drop(columns = ['FuelChoice'])
X = pd.get_dummies(X, columns = ['Community name', 'Where do you normally cook? ', 'Civil state', 'House'], drop_first = True)
X.head()
# Out:
#    What is the family's monthly income? (Brazil´s Minimum Wage R$937.00)  \
# 2                                                2.0
# 3                                                2.0
# 5                                                3.0
# 6                                                3.0
# 7                                                3.0
#
#    Resident:  Permanent   Gender (M or F)  Age  Education  \
# 2                    1.0              2.0    3        3.0
# 3                    1.0              1.0    2        4.0
# 5                    1.0              2.0    1        3.0
# 6                    1.0              1.0    1        3.0
# 7                    1.0              1.0    4        6.0
#
#    How many meals a day?   . How many people eat at home daily?   \
# 2                     4.0                                    2.0
# 3                     3.0                                    4.0
# 5                     3.0                                    3.0
# 6                     3.0                                    4.0
# 7                     4.0                                    4.0
#
#    How many contribute to the family's monthly income?   Number_Men  \
# 2                                                2.0              1
# 3                                                1.0              2
# 5                                                1.0              1
# 6                                                1.0              2
# 7                                                2.0              3
#
#    Number_Women  ...  Community name_8  Community name_9  Community name_10  \
# 2             1  ...                 0                 0                  0
# 3             2  ...                 0                 0                  0
# 5             2  ...                 0                 0                  0
# 6             2  ...                 0                 0                  0
# 7             1  ...                 0                 0                  0
#
#    Community name_11  Community name_12  Community name_13  Community name_14  \
# 2                  0                  0                  0                  0
# 3                  0                  0                  0                  0
# 5                  0                  0                  0                  0
# 6                  0                  0                  0                  0
# 7                  0                  0                  0                  0
#
#    Where do you normally cook? _3.0  Civil state_2.0  House_2.0
# 2                                 1                1          0
# 3                                 1                0          0
# 5                                 1                0          0
# 6                                 1                1          0
# 7                                 1                1          0
#
# [5 rows x 26 columns]

# %%
X.columns.values
# Out:
# array(["What is the family's monthly income? (Brazil´s Minimum Wage R$937.00)",
#        'Resident:  Permanent ', 'Gender (M or F)', 'Age', 'Education',
#        'How many meals a day? ', '. How many people eat at home daily? ',
#        "How many contribute to the family's monthly income? ",
#        'Number_Men', 'Number_Women', 'Community name_2',
#        'Community name_3', 'Community name_4', 'Community name_5',
#        'Community name_6', 'Community name_7', 'Community name_8',
#        'Community name_9', 'Community name_10', 'Community name_11',
#        'Community name_12', 'Community name_13', 'Community name_14',
#        'Where do you normally cook? _3.0', 'Civil state_2.0', 'House_2.0'],
#       dtype=object)

# %%
gammavals = np.arange(0, 0.5, 0.01)

kf = KFold(n_splits=5, random_state=42, shuffle=True)
loo = LeaveOneOut()
Xs = MinMaxScaler().fit_transform(X)
Xs = pd.DataFrame(Xs); Xs.columns = X.columns.values; Xs.index = X.index

Xc = sm.add_constant(Xs)
best_acc = -np.inf
for gamma in gammavals:
    print('gamma =', gamma)
        
    acc_list = []
    #for train_index, test_index in kf.split(Xc):   
        
    #    Xtrain, Xtest = Xc.iloc[train_index], Xc.iloc[test_index]
    #    ytrain, ytest = y.iloc[train_index], y.iloc[test_index]
        
    #    nunique = Xtrain.apply(pd.Series.nunique)
    #    cols_to_drop = nunique[nunique == 1].index
  
    #   Xtest = Xtest.drop(cols_to_drop, axis=1)
    #    Xtrain = Xtrain.drop(cols_to_drop, axis=1)
    
    #    MNLogitMdl = MNLogit(ytrain, Xtrain)
    #    results = MNLogitMdl.fit_regularized(method = 'l1', alpha = gamma, full_output = True, disp = False)

    #    ypred = np.argmax(results.predict(Xtest, linear = True).values, axis = 1) + 1
    #    acc_list.append(Acc(ytest.values, ypred))
    
    MNLogitMdl = MNLogit(y, Xc)
    results = MNLogitMdl.fit_regularized(method = 'l1', alpha = gamma, full_output = True, disp = False)
    ypred = np.argmax(results.predict(Xc, linear = True).values, axis = 1) + 1
    acc_list.append(Acc(y.values, ypred))
    
    acc = np.mean(acc_list)
    print('accuracy = ', acc)
    
    if acc > best_acc:
        best_acc = acc
        gamma_opt = gamma

print(gamma_opt, best_acc)
# Out:
# gamma = 0.0
# accuracy =  0.6412213740458015
# gamma = 0.01
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\l1_solvers_common.py:71: ConvergenceWarning: QC check did not pass for 3 out of 81 parameters
# Try increasing solver accuracy or number of iterations, decreasing alpha, or switch solvers
#   warnings.warn(message, ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\l1_solvers_common.py:144: ConvergenceWarning: Could not trim params automatically due to failed QC check. Trimming using trim_mode == 'size' will still work.
#   warnings.warn(msg, ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# accuracy =  0.6412213740458015
# gamma = 0.02
# accuracy =  0.5038167938931297
# gamma = 0.03
# accuracy =  0.6183206106870229
# gamma = 0.04
# accuracy =  0.648854961832061
# gamma = 0.05
# accuracy =  0.6564885496183206
# gamma = 0.06
# accuracy =  0.6564885496183206
# gamma = 0.07
# accuracy =  0.6412213740458015
# gamma = 0.08
# accuracy =  0.6335877862595419
# gamma = 0.09
# accuracy =  0.6335877862595419
# gamma = 0.1
# accuracy =  0.6259541984732825
# gamma = 0.11
# accuracy =  0.6335877862595419
# gamma = 0.12
# accuracy =  0.6335877862595419
# gamma = 0.13
# accuracy =  0.6335877862595419
# gamma = 0.14
# accuracy =  0.6183206106870229
# gamma = 0.15
# accuracy =  0.6183206106870229
# gamma = 0.16
# accuracy =  0.6183206106870229
# gamma = 0.17
# accuracy =  0.6183206106870229
# gamma = 0.18
# accuracy =  0.6183206106870229
# gamma = 0.19
# accuracy =  0.6183206106870229
# gamma = 0.2
# accuracy =  0.6259541984732825
# gamma = 0.21
# accuracy =  0.6183206106870229
# gamma = 0.22
# accuracy =  0.6106870229007634
# gamma = 0.23
# accuracy =  0.6106870229007634
# gamma = 0.24
# accuracy =  0.5954198473282443
# gamma = 0.25
# accuracy =  0.5877862595419847
# gamma = 0.26
# accuracy =  0.5877862595419847
# gamma = 0.27
# accuracy =  0.5954198473282443
# gamma = 0.28
# accuracy =  0.5954198473282443
# gamma = 0.29
# accuracy =  0.5954198473282443
# gamma = 0.3
# accuracy =  0.5954198473282443
# gamma = 0.31
# accuracy =  0.5954198473282443
# gamma = 0.32
# accuracy =  0.6030534351145038
# gamma = 0.33
# accuracy =  0.6030534351145038
# gamma = 0.34
# accuracy =  0.6030534351145038
# gamma = 0.35000000000000003
# accuracy =  0.6030534351145038
# gamma = 0.36
# accuracy =  0.6030534351145038
# gamma = 0.37
# accuracy =  0.5877862595419847
# gamma = 0.38
# accuracy =  0.5877862595419847
# gamma = 0.39
# accuracy =  0.5877862595419847
# gamma = 0.4
# accuracy =  0.5877862595419847
# gamma = 0.41000000000000003
# accuracy =  0.5877862595419847
# gamma = 0.42
# accuracy =  0.5954198473282443
# gamma = 0.43
# accuracy =  0.5877862595419847
# gamma = 0.44
# accuracy =  0.5877862595419847
# gamma = 0.45
# accuracy =  0.5877862595419847
# gamma = 0.46
# accuracy =  0.5877862595419847
# gamma = 0.47000000000000003
# accuracy =  0.5877862595419847
# gamma = 0.48
# accuracy =  0.5725190839694656
# gamma = 0.49
# accuracy =  0.5801526717557252
# 0.05 0.6564885496183206

# %%
MNLogitMdl = MNLogit(y, Xc)
bestResults = MNLogitMdl.fit_regularized(method = 'l1', alpha = gamma_opt, full_output = True, disp = False)

# %%
MNLogitMdl = MNLogit(y, Xc)
baseResults = MNLogitMdl.fit_regularized(method = 'l1', alpha = 0, full_output = True, disp = False)

# %%
pvals = bestResults.pvalues.values
coefs = bestResults.params.values

table = np.column_stack(([coefs[1:,0], pvals[1:,0], coefs[1:,1], pvals[1:,1], coefs[1:,2], pvals[1:,2]]))
df = pd.DataFrame(table)
df.index = X.columns
df = df.dropna()
df.columns = ['weight_{G,C,F}', 'pval_{G,C,F}', 'weight_{G,F}', 'pval_{G,F}', 'weight_{G}', 'pval_{G}']
df
# Out:
#                                                     weight_{G,C,F}  \
# What is the family's monthly income? (Brazil´s ...       -5.017123
# Resident:  Permanent                                     -2.332391
# Gender (M or F)                                          -0.970940
# Age                                                      -2.210070
# Education                                                -0.182376
# How many meals a day?                                     1.495146
# . How many people eat at home daily?                      5.988167
# How many contribute to the family's monthly inc...        1.351928
# Number_Women                                             -1.251296
# Community name_2                                          0.234539
# Community name_4                                          2.946463
# Community name_5                                          1.662134
# Community name_6                                         -0.522502
# Community name_7                                         -0.007555
# Community name_8                                         -0.650829
# Community name_10                                         1.724819
# Community name_12                                         0.168583
# Where do you normally cook? _3.0                         -0.490580
# Civil state_2.0                                           0.458184
# House_2.0                                                -3.810793
#
#                                                     pval_{G,C,F}  \
# What is the family's monthly income? (Brazil´s ...      0.054187
# Resident:  Permanent                                    0.385247
# Gender (M or F)                                         0.251413
# Age                                                     0.126844
# Education                                               0.926046
# How many meals a day?                                   0.501187
# . How many people eat at home daily?                    0.306820
# How many contribute to the family's monthly inc...      0.668925
# Number_Women                                            0.609974
# Community name_2                                        0.882414
# Community name_4                                        0.315701
# Community name_5                                        0.558376
# Community name_6                                        0.696872
# Community name_7                                        0.998876
# Community name_8                                        0.651099
# Community name_10                                       0.328825
# Community name_12                                       0.904488
# Where do you normally cook? _3.0                        0.863898
# Civil state_2.0                                         0.599620
# House_2.0                                               0.436420
#
#                                                     weight_{G,F}  pval_{G,F}  \
# What is the family's monthly income? (Brazil´s ...      0.824192    0.737796
# Resident:  Permanent                                   -1.349157    0.604573
# Gender (M or F)                                        -0.566864    0.563024
# Age                                                    -0.843154    0.608636
# Education                                              -1.246345    0.547374
# How many meals a day?                                   2.482171    0.299470
# . How many people eat at home daily?                   11.113638    0.091443
# How many contribute to the family's monthly inc...      1.642034    0.625909
# Number_Women                                           -2.307783    0.426275
# Community name_2                                        0.714718    0.757502
# Community name_4                                        4.679522    0.148687
# Community name_5                                        3.502040    0.275796
# Community name_6                                       -0.272707    0.899245
# Community name_7                                        4.885425    0.352434
# Community name_8                                        1.658528    0.401105
# Community name_10                                       2.325196    0.334460
# Community name_12                                       1.150636    0.571365
# Where do you normally cook? _3.0                       -2.067487    0.466491
# Civil state_2.0                                         0.842147    0.404873
# House_2.0                                               0.380435    0.866859
#
#                                                     weight_{G}  pval_{G}
# What is the family's monthly income? (Brazil´s ...   -1.580017  0.480422
# Resident:  Permanent                                 -1.919843  0.451629
# Gender (M or F)                                      -0.535406  0.539128
# Age                                                  -0.684768  0.648172
# Education                                             0.954495  0.632468
# How many meals a day?                                 2.007869  0.383923
# . How many people eat at home daily?                  4.019533  0.591104
# How many contribute to the family's monthly inc...   -1.127198  0.746505
# Number_Women                                         -1.275258  0.657655
# Community name_2                                     -1.030303  0.513402
# Community name_4                                      2.630078  0.360710
# Community name_5                                      1.656405  0.552309
# Community name_6                                     -0.996211  0.440913
# Community name_7                                      0.922914  0.859007
# Community name_8                                     -1.687560  0.268551
# Community name_10                                    -0.357338  0.838714
# Community name_12                                    -1.576013  0.318509
# Where do you normally cook? _3.0                      1.770480  0.559416
# Civil state_2.0                                       1.171706  0.212815
# House_2.0                                             1.376240  0.497884

# %%
##Added By Nandor
# Modify and print to LaTeX
display(df)
df_int = df.copy(deep=True)

change_name = {
"What is the family's monthly income? (Brazil´s Minimum Wage R$937.00)" : "Monthly Income of the Family",
 'Resident:  Permanent ' : "Residence",
 'Gender (M or F)': "Gender of Household Head",
 'Age' : "Age of Household Head",
 'Education': "Education of Household Head",
 'How many meals a day? ' : "Number of meals per day",
 '. How many people eat at home daily? ': "Number of people at meals daily",
 "How many contribute to the family's monthly income? ": "Number of people contributing to the monthly income",
 'Civil state_2.0':"Civil Status of Household Head",
 'House_2.0':"House Ownership"
}

#Community names from cleaning notebook
comm_name =  {'Aruaú': 1,
                    'Baixote': 2,
                    'Chita': 3,
                    'Marajá': 4,
                    'Monte Sinai': 5,
                    'Nova Esperança': 6,
                    'Nova Sugar caneã': 7,
                    'Pagodão': 8,
                    'Santa Isabel': 9,
                    'Santo Antônio': 10,
                    'São Tomé': 11,
                    'Terra Preta': 12,
                    'Tiririca': 13,
                    'Três unitos': 14}
#reverse_dict
comm_name = {comm_name[x]:x for x in comm_name}

#Modify For Print
df_int['Variable Name'] = df_int.index

for change in change_name:
    df_int.loc[df_int['Variable Name']==change,'Variable Name']= change_name[change]
    df_int.rename(index={change:change_name[change]},inplace=True)
    
for v_n in list(df_int['Variable Name'].values):
    if "Community name" in v_n:
        df_int.loc[df_int['Variable Name']==v_n,'Variable Name']= "qquad "+comm_name[int(v_n.split("_")[1])]
        df_int.rename(index={v_n:"Community name_"+comm_name[int(v_n.split("_")[1])]},inplace=True)
        
df_int.loc["Community name","Variable Name"]= "Community name"
df_int.sort_index(inplace=True)

df_int = df_int[["Variable Name","weight_{G,C,F}","pval_{G,C,F}","weight_{G,F}","pval_{G,F}","weight_{G}","pval_{G}"]]
display(df_int)
df_int.to_csv('table6.csv')

def raw(x):
    return x

def format_w(x):
    if np.isnan(x):
        return ""
    else:
        return '%.2f' % x

def format_p(x):
    if np.isnan(x):
        return ""
    else:
        return '%.4f' % x

with pd.option_context("max_colwidth", 1000):
    string_tex = df_int.to_latex(header = False, formatters=[raw,format_w,format_p,format_w,format_p,format_w,format_p],multirow=True,index=False)

add_header = """ 
\\begin{tabular}{|p{5.5cm}|p{1.2cm}p{1.2cm}|p{1.2cm}p{1.2cm}|p{1.2cm}p{1.2cm}|}
                \\toprule
				&\\multicolumn{2}{c|}{G, C, F}&\\multicolumn{2}{c|}{G, F}&\\multicolumn{2}{c|}{G}\\\\
				\\cline{2-3}\\cline{4-5}\\cline{6-7}
				
				Variable name & $w_4$ & p-value& $w_5$ & p-value & $w_6$ & p-value \\\\
				\midrule
"""
string_tex = string_tex.replace("qquad","\\qquad")

string_tex = add_header + string_tex.split("toprule")[1]

with open("table6_format.tex", "wb") as text_file: 
    text_file.write(string_tex.encode('utf8'))
# Out:
#                                                     weight_{G,C,F}  \
# What is the family's monthly income? (Brazil´s ...       -5.017123
# Resident:  Permanent                                     -2.332391
# Gender (M or F)                                          -0.970940
# Age                                                      -2.210070
# Education                                                -0.182376
# How many meals a day?                                     1.495146
# . How many people eat at home daily?                      5.988167
# How many contribute to the family's monthly inc...        1.351928
# Number_Women                                             -1.251296
# Community name_2                                          0.234539
# Community name_4                                          2.946463
# Community name_5                                          1.662134
# Community name_6                                         -0.522502
# Community name_7                                         -0.007555
# Community name_8                                         -0.650829
# Community name_10                                         1.724819
# Community name_12                                         0.168583
# Where do you normally cook? _3.0                         -0.490580
# Civil state_2.0                                           0.458184
# House_2.0                                                -3.810793
#
#                                                     pval_{G,C,F}  \
# What is the family's monthly income? (Brazil´s ...      0.054187
# Resident:  Permanent                                    0.385247
# Gender (M or F)                                         0.251413
# Age                                                     0.126844
# Education                                               0.926046
# How many meals a day?                                   0.501187
# . How many people eat at home daily?                    0.306820
# How many contribute to the family's monthly inc...      0.668925
# Number_Women                                            0.609974
# Community name_2                                        0.882414
# Community name_4                                        0.315701
# Community name_5                                        0.558376
# Community name_6                                        0.696872
# Community name_7                                        0.998876
# Community name_8                                        0.651099
# Community name_10                                       0.328825
# Community name_12                                       0.904488
# Where do you normally cook? _3.0                        0.863898
# Civil state_2.0                                         0.599620
# House_2.0                                               0.436420
#
#                                                     weight_{G,F}  pval_{G,F}  \
# What is the family's monthly income? (Brazil´s ...      0.824192    0.737796
# Resident:  Permanent                                   -1.349157    0.604573
# Gender (M or F)                                        -0.566864    0.563024
# Age                                                    -0.843154    0.608636
# Education                                              -1.246345    0.547374
# How many meals a day?                                   2.482171    0.299470
# . How many people eat at home daily?                   11.113638    0.091443
# How many contribute to the family's monthly inc...      1.642034    0.625909
# Number_Women                                           -2.307783    0.426275
# Community name_2                                        0.714718    0.757502
# Community name_4                                        4.679522    0.148687
# Community name_5                                        3.502040    0.275796
# Community name_6                                       -0.272707    0.899245
# Community name_7                                        4.885425    0.352434
# Community name_8                                        1.658528    0.401105
# Community name_10                                       2.325196    0.334460
# Community name_12                                       1.150636    0.571365
# Where do you normally cook? _3.0                       -2.067487    0.466491
# Civil state_2.0                                         0.842147    0.404873
# House_2.0                                               0.380435    0.866859
#
#                                                     weight_{G}  pval_{G}
# What is the family's monthly income? (Brazil´s ...   -1.580017  0.480422
# Resident:  Permanent                                 -1.919843  0.451629
# Gender (M or F)                                      -0.535406  0.539128
# Age                                                  -0.684768  0.648172
# Education                                             0.954495  0.632468
# How many meals a day?                                 2.007869  0.383923
# . How many people eat at home daily?                  4.019533  0.591104
# How many contribute to the family's monthly inc...   -1.127198  0.746505
# Number_Women                                         -1.275258  0.657655
# Community name_2                                     -1.030303  0.513402
# Community name_4                                      2.630078  0.360710
# Community name_5                                      1.656405  0.552309
# Community name_6                                     -0.996211  0.440913
# Community name_7                                      0.922914  0.859007
# Community name_8                                     -1.687560  0.268551
# Community name_10                                    -0.357338  0.838714
# Community name_12                                    -1.576013  0.318509
# Where do you normally cook? _3.0                      1.770480  0.559416
# Civil state_2.0                                       1.171706  0.212815
# House_2.0                                             1.376240  0.497884
#                                                                                         Variable Name  \
# Age of Household Head                                                           Age of Household Head
# Civil Status of Household Head                                         Civil Status of Household Head
# Community name                                                                         Community name
# Community name_Baixote                                                                  qquad Baixote
# Community name_Marajá                                                                    qquad Marajá
# Community name_Monte Sinai                                                          qquad Monte Sinai
# Community name_Nova Esperança                                                    qquad Nova Esperança
# Community name_Nova Sugar caneã                                                qquad Nova Sugar caneã
# Community name_Pagodão                                                                  qquad Pagodão
# Community name_Santo Antônio                                                      qquad Santo Antônio
# Community name_Terra Preta                                                          qquad Terra Preta
# Education of Household Head                                               Education of Household Head
# Gender of Household Head                                                     Gender of Household Head
# House Ownership                                                                       House Ownership
# Monthly Income of the Family                                             Monthly Income of the Family
# Number of meals per day                                                       Number of meals per day
# Number of people at meals daily                                       Number of people at meals daily
# Number of people contributing to the monthly in...  Number of people contributing to the monthly i...
# Number_Women                                                                             Number_Women
# Residence                                                                                   Residence
# Where do you normally cook? _3.0                                     Where do you normally cook? _3.0
#
#                                                     weight_{G,C,F}  \
# Age of Household Head                                    -2.210070
# Civil Status of Household Head                            0.458184
# Community name                                                 NaN
# Community name_Baixote                                    0.234539
# Community name_Marajá                                     2.946463
# Community name_Monte Sinai                                1.662134
# Community name_Nova Esperança                            -0.522502
# Community name_Nova Sugar caneã                          -0.007555
# Community name_Pagodão                                   -0.650829
# Community name_Santo Antônio                              1.724819
# Community name_Terra Preta                                0.168583
# Education of Household Head                              -0.182376
# Gender of Household Head                                 -0.970940
# House Ownership                                          -3.810793
# Monthly Income of the Family                             -5.017123
# Number of meals per day                                   1.495146
# Number of people at meals daily                           5.988167
# Number of people contributing to the monthly in...        1.351928
# Number_Women                                             -1.251296
# Residence                                                -2.332391
# Where do you normally cook? _3.0                         -0.490580
#
#                                                     pval_{G,C,F}  \
# Age of Household Head                                   0.126844
# Civil Status of Household Head                          0.599620
# Community name                                               NaN
# Community name_Baixote                                  0.882414
# Community name_Marajá                                   0.315701
# Community name_Monte Sinai                              0.558376
# Community name_Nova Esperança                           0.696872
# Community name_Nova Sugar caneã                         0.998876
# Community name_Pagodão                                  0.651099
# Community name_Santo Antônio                            0.328825
# Community name_Terra Preta                              0.904488
# Education of Household Head                             0.926046
# Gender of Household Head                                0.251413
# House Ownership                                         0.436420
# Monthly Income of the Family                            0.054187
# Number of meals per day                                 0.501187
# Number of people at meals daily                         0.306820
# Number of people contributing to the monthly in...      0.668925
# Number_Women                                            0.609974
# Residence                                               0.385247
# Where do you normally cook? _3.0                        0.863898
#
#                                                     weight_{G,F}  pval_{G,F}  \
# Age of Household Head                                  -0.843154    0.608636
# Civil Status of Household Head                          0.842147    0.404873
# Community name                                               NaN         NaN
# Community name_Baixote                                  0.714718    0.757502
# Community name_Marajá                                   4.679522    0.148687
# Community name_Monte Sinai                              3.502040    0.275796
# Community name_Nova Esperança                          -0.272707    0.899245
# Community name_Nova Sugar caneã                         4.885425    0.352434
# Community name_Pagodão                                  1.658528    0.401105
# Community name_Santo Antônio                            2.325196    0.334460
# Community name_Terra Preta                              1.150636    0.571365
# Education of Household Head                            -1.246345    0.547374
# Gender of Household Head                               -0.566864    0.563024
# House Ownership                                         0.380435    0.866859
# Monthly Income of the Family                            0.824192    0.737796
# Number of meals per day                                 2.482171    0.299470
# Number of people at meals daily                        11.113638    0.091443
# Number of people contributing to the monthly in...      1.642034    0.625909
# Number_Women                                           -2.307783    0.426275
# Residence                                              -1.349157    0.604573
# Where do you normally cook? _3.0                       -2.067487    0.466491
#
#                                                     weight_{G}  pval_{G}
# Age of Household Head                                -0.684768  0.648172
# Civil Status of Household Head                        1.171706  0.212815
# Community name                                             NaN       NaN
# Community name_Baixote                               -1.030303  0.513402
# Community name_Marajá                                 2.630078  0.360710
# Community name_Monte Sinai                            1.656405  0.552309
# Community name_Nova Esperança                        -0.996211  0.440913
# Community name_Nova Sugar caneã                       0.922914  0.859007
# Community name_Pagodão                               -1.687560  0.268551
# Community name_Santo Antônio                         -0.357338  0.838714
# Community name_Terra Preta                           -1.576013  0.318509
# Education of Household Head                           0.954495  0.632468
# Gender of Household Head                             -0.535406  0.539128
# House Ownership                                       1.376240  0.497884
# Monthly Income of the Family                         -1.580017  0.480422
# Number of meals per day                               2.007869  0.383923
# Number of people at meals daily                       4.019533  0.591104
# Number of people contributing to the monthly in...   -1.127198  0.746505
# Number_Women                                         -1.275258  0.657655
# Residence                                            -1.919843  0.451629
# Where do you normally cook? _3.0                      1.770480  0.559416

# %%
df.shape
# Out:
# (20, 6)

# %%
pvals = baseResults.pvalues.values
coefs = baseResults.params.values

table = np.column_stack(([coefs[1:,0], pvals[1:,0], coefs[1:,1], pvals[1:,1], coefs[1:,2], pvals[1:,2]]))
df_base = pd.DataFrame(table)
df_base.index = X.columns
#df_base = df_base.dropna()
df_base.columns = ['weight_{G,C,F}', 'pval_{G,C,F}', 'weight_{G,F}', 'pval_{G,F}', 'weight_{G}', 'pval_{G}']
df_base
# Out:
#                                                     weight_{G,C,F}  \
# What is the family's monthly income? (Brazil´s ...       -5.075563
# Resident:  Permanent                                    -12.657528
# Gender (M or F)                                          -1.242361
# Age                                                      -4.619220
# Education                                                -2.244878
# How many meals a day?                                     2.174695
# . How many people eat at home daily?                     22.508330
# How many contribute to the family's monthly inc...        4.236916
# Number_Men                                               -4.766971
# Number_Women                                             -6.130529
# Community name_2                                          0.969264
# Community name_3                                         13.222499
# Community name_4                                         13.504829
# Community name_5                                          9.956167
# Community name_6                                         -0.219286
# Community name_7                                          4.528651
# Community name_8                                         -0.045175
# Community name_9                                         23.256251
# Community name_10                                         3.641945
# Community name_11                                        24.625012
# Community name_12                                         1.751577
# Community name_13                                        15.960117
# Community name_14                                         1.806068
# Where do you normally cook? _3.0                         -9.323084
# Civil state_2.0                                           1.162254
# House_2.0                                               -24.598965
#
#                                                     pval_{G,C,F}  \
# What is the family's monthly income? (Brazil´s ...      0.090042
# Resident:  Permanent                                    0.957208
# Gender (M or F)                                         0.222715
# Age                                                     0.023717
# Education                                               0.379449
# How many meals a day?                                   0.426737
# . How many people eat at home daily?                    0.095501
# How many contribute to the family's monthly inc...      0.311567
# Number_Men                                              0.337121
# Number_Women                                            0.115519
# Community name_2                                        0.589303
# Community name_3                                        0.960351
# Community name_4                                        0.937191
# Community name_5                                        0.924547
# Community name_6                                        0.887989
# Community name_7                                        0.998635
# Community name_8                                        0.977006
# Community name_9                                        0.999881
# Community name_10                                       0.072397
# Community name_11                                       0.999690
# Community name_12                                       0.285914
# Community name_13                                       0.985697
# Community name_14                                       0.349317
# Where do you normally cook? _3.0                        0.968555
# Civil state_2.0                                         0.292896
# House_2.0                                               0.999877
#
#                                                     weight_{G,F}  pval_{G,F}  \
# What is the family's monthly income? (Brazil´s ...      1.486227    0.599860
# Resident:  Permanent                                  -11.536068    0.960997
# Gender (M or F)                                        -0.862858    0.453265
# Age                                                    -3.386651    0.133429
# Education                                              -3.406284    0.201123
# How many meals a day?                                   3.441667    0.238143
# . How many people eat at home daily?                   28.885913    0.036423
# How many contribute to the family's monthly inc...      4.590322    0.288693
# Number_Men                                             -5.312839    0.298972
# Number_Women                                           -7.788979    0.069035
# Community name_2                                        8.552948    0.879424
# Community name_3                                       19.820894    0.941883
# Community name_4                                       22.289284    0.901669
# Community name_5                                       18.839594    0.874494
# Community name_6                                        6.778622    0.904290
# Community name_7                                       16.766535    0.994947
# Community name_8                                        9.339442    0.868394
# Community name_9                                       -7.382829    1.000000
# Community name_10                                      11.257951    0.841749
# Community name_11                                      -7.875465    1.000000
# Community name_12                                       9.784993    0.862190
# Community name_13                                     -13.107598    1.000000
# Community name_14                                      11.016996    0.845055
# Where do you normally cook? _3.0                      -10.845326    0.963425
# Civil state_2.0                                         1.649915    0.183498
# House_2.0                                               0.481118    0.852599
#
#                                                     weight_{G}  pval_{G}
# What is the family's monthly income? (Brazil´s ...   -1.428691  0.573171
# Resident:  Permanent                                -11.998912  0.959432
# Gender (M or F)                                      -0.812542  0.429123
# Age                                                  -2.953299  0.153426
# Education                                            -0.935312  0.715788
# How many meals a day?                                 2.625428  0.346022
# . How many people eat at home daily?                 22.028540  0.116644
# How many contribute to the family's monthly inc...    1.479929  0.741942
# Number_Men                                           -6.183432  0.236448
# Number_Women                                         -6.614422  0.120548
# Community name_2                                     -0.456938  0.801879
# Community name_3                                     10.109015  0.969682
# Community name_4                                     13.025750  0.939414
# Community name_5                                      9.811392  0.925640
# Community name_6                                     -0.760155  0.635875
# Community name_7                                      5.673387  0.998290
# Community name_8                                     -1.264585  0.456192
# Community name_9                                     -8.918697  0.999999
# Community name_10                                     1.269677  0.538653
# Community name_11                                    -8.418131  0.999999
# Community name_12                                    -0.150355  0.934934
# Community name_13                                    14.539507  0.986970
# Community name_14                                     1.112148  0.556840
# Where do you normally cook? _3.0                     15.866468  0.999970
# Civil state_2.0                                       1.964613  0.090317
# House_2.0                                             1.660881  0.476203

# %%
df_base.shape
# Out:
# (26, 6)

# %% [markdown]
# # Reference: Gas and Charcoal

# %%
##Added By Nandor
# Modify and print to LaTeX
display(df_base)
df_int = df_base.copy(deep=True)

change_name = {
"What is the family's monthly income? (Brazil´s Minimum Wage R$937.00)" : "Monthly Income of the Family",
 'Resident:  Permanent ' : "Residence",
 'Gender (M or F)': "Gender of Household Head",
 'Age' : "Age of Household Head",
 'Education': "Education of Household Head",
  "Number_Men":"Number of Men in Household",
  "Number_Women":"Number of Women in Household",
 'How many meals a day? ' : "Number of meals per day",
 '. How many people eat at home daily? ': "Number of people at meals daily",
 "How many contribute to the family's monthly income? ": "Number of people contributing to the monthly income",
 'Civil state_2.0':"Civil Status of Household Head",
 'House_2.0':"House Ownership",
  "Where do you normally cook? _3.0":"Normal Cooking Area"
}

#Community names from cleaning notebook
comm_name =  {'Aruaú': 1,
                    'Baixote': 2,
                    'Chita': 3,
                    'Marajá': 4,
                    'Monte Sinai': 5,
                    'Nova Esperança': 6,
                    'Nova Sugar caneã': 7,
                    'Pagodão': 8,
                    'Santa Isabel': 9,
                    'Santo Antônio': 10,
                    'São Tomé': 11,
                    'Terra Preta': 12,
                    'Tiririca': 13,
                    'Três unitos': 14}
#reverse_dict
comm_name = {comm_name[x]:x for x in comm_name}

#Modify For Print
df_int['Variable Name'] = df_int.index

for change in change_name:
    df_int.loc[df_int['Variable Name']==change,'Variable Name']= change_name[change]
    df_int.rename(index={change:change_name[change]},inplace=True)
    
for v_n in list(df_int['Variable Name'].values):
    if "Community name" in v_n:
        df_int.loc[df_int['Variable Name']==v_n,'Variable Name']= "qquad "+comm_name[int(v_n.split("_")[1])]
        df_int.rename(index={v_n:"Community name_"+comm_name[int(v_n.split("_")[1])]},inplace=True)
        
df_int.loc["Community name","Variable Name"]= "Community name"
df_int.sort_index(inplace=True)

df_int = df_int[["Variable Name","weight_{G,C,F}","pval_{G,C,F}","weight_{G,F}","pval_{G,F}","weight_{G}","pval_{G}"]]
display(df_int)
df_int.to_csv('table6.csv')

def raw(x):
    return x

def format_w(x):
    if np.isnan(x):
        return ""
    else:
        return '%.2f' % x

def format_p(x):
    if np.isnan(x):
        return ""
    else:
        return '%.4f' % x

with pd.option_context("max_colwidth", 1000):
    string_tex = df_int.to_latex(header = False, formatters=[raw,format_w,format_p,format_w,format_p,format_w,format_p],multirow=True,index=False)

add_header = """ 
\\begin{tabular}{|p{5.5cm}|p{1.2cm}p{1.2cm}|p{1.2cm}p{1.2cm}|p{1.2cm}p{1.2cm}|}
                \\toprule
				&\\multicolumn{2}{c|}{G, C, F}&\\multicolumn{2}{c|}{G, F}&\\multicolumn{2}{c|}{G}\\\\
				\\cline{2-3}\\cline{4-5}\\cline{6-7}
				
				Variable name & $w_4$ & p-value& $w_5$ & p-value & $w_6$ & p-value \\\\
				\midrule
"""
string_tex = string_tex.replace("qquad","\\qquad")

string_tex = add_header + string_tex.split("toprule")[1]

with open("table8_format.tex", "wb") as text_file: 
    text_file.write(string_tex.encode('utf8'))
# Out:
#                                                     weight_{G,C,F}  \
# What is the family's monthly income? (Brazil´s ...       -5.075563
# Resident:  Permanent                                    -12.657528
# Gender (M or F)                                          -1.242361
# Age                                                      -4.619220
# Education                                                -2.244878
# How many meals a day?                                     2.174695
# . How many people eat at home daily?                     22.508330
# How many contribute to the family's monthly inc...        4.236916
# Number_Men                                               -4.766971
# Number_Women                                             -6.130529
# Community name_2                                          0.969264
# Community name_3                                         13.222499
# Community name_4                                         13.504829
# Community name_5                                          9.956167
# Community name_6                                         -0.219286
# Community name_7                                          4.528651
# Community name_8                                         -0.045175
# Community name_9                                         23.256251
# Community name_10                                         3.641945
# Community name_11                                        24.625012
# Community name_12                                         1.751577
# Community name_13                                        15.960117
# Community name_14                                         1.806068
# Where do you normally cook? _3.0                         -9.323084
# Civil state_2.0                                           1.162254
# House_2.0                                               -24.598965
#
#                                                     pval_{G,C,F}  \
# What is the family's monthly income? (Brazil´s ...      0.090042
# Resident:  Permanent                                    0.957208
# Gender (M or F)                                         0.222715
# Age                                                     0.023717
# Education                                               0.379449
# How many meals a day?                                   0.426737
# . How many people eat at home daily?                    0.095501
# How many contribute to the family's monthly inc...      0.311567
# Number_Men                                              0.337121
# Number_Women                                            0.115519
# Community name_2                                        0.589303
# Community name_3                                        0.960351
# Community name_4                                        0.937191
# Community name_5                                        0.924547
# Community name_6                                        0.887989
# Community name_7                                        0.998635
# Community name_8                                        0.977006
# Community name_9                                        0.999881
# Community name_10                                       0.072397
# Community name_11                                       0.999690
# Community name_12                                       0.285914
# Community name_13                                       0.985697
# Community name_14                                       0.349317
# Where do you normally cook? _3.0                        0.968555
# Civil state_2.0                                         0.292896
# House_2.0                                               0.999877
#
#                                                     weight_{G,F}  pval_{G,F}  \
# What is the family's monthly income? (Brazil´s ...      1.486227    0.599860
# Resident:  Permanent                                  -11.536068    0.960997
# Gender (M or F)                                        -0.862858    0.453265
# Age                                                    -3.386651    0.133429
# Education                                              -3.406284    0.201123
# How many meals a day?                                   3.441667    0.238143
# . How many people eat at home daily?                   28.885913    0.036423
# How many contribute to the family's monthly inc...      4.590322    0.288693
# Number_Men                                             -5.312839    0.298972
# Number_Women                                           -7.788979    0.069035
# Community name_2                                        8.552948    0.879424
# Community name_3                                       19.820894    0.941883
# Community name_4                                       22.289284    0.901669
# Community name_5                                       18.839594    0.874494
# Community name_6                                        6.778622    0.904290
# Community name_7                                       16.766535    0.994947
# Community name_8                                        9.339442    0.868394
# Community name_9                                       -7.382829    1.000000
# Community name_10                                      11.257951    0.841749
# Community name_11                                      -7.875465    1.000000
# Community name_12                                       9.784993    0.862190
# Community name_13                                     -13.107598    1.000000
# Community name_14                                      11.016996    0.845055
# Where do you normally cook? _3.0                      -10.845326    0.963425
# Civil state_2.0                                         1.649915    0.183498
# House_2.0                                               0.481118    0.852599
#
#                                                     weight_{G}  pval_{G}
# What is the family's monthly income? (Brazil´s ...   -1.428691  0.573171
# Resident:  Permanent                                -11.998912  0.959432
# Gender (M or F)                                      -0.812542  0.429123
# Age                                                  -2.953299  0.153426
# Education                                            -0.935312  0.715788
# How many meals a day?                                 2.625428  0.346022
# . How many people eat at home daily?                 22.028540  0.116644
# How many contribute to the family's monthly inc...    1.479929  0.741942
# Number_Men                                           -6.183432  0.236448
# Number_Women                                         -6.614422  0.120548
# Community name_2                                     -0.456938  0.801879
# Community name_3                                     10.109015  0.969682
# Community name_4                                     13.025750  0.939414
# Community name_5                                      9.811392  0.925640
# Community name_6                                     -0.760155  0.635875
# Community name_7                                      5.673387  0.998290
# Community name_8                                     -1.264585  0.456192
# Community name_9                                     -8.918697  0.999999
# Community name_10                                     1.269677  0.538653
# Community name_11                                    -8.418131  0.999999
# Community name_12                                    -0.150355  0.934934
# Community name_13                                    14.539507  0.986970
# Community name_14                                     1.112148  0.556840
# Where do you normally cook? _3.0                     15.866468  0.999970
# Civil state_2.0                                       1.964613  0.090317
# House_2.0                                             1.660881  0.476203
#                                                                                         Variable Name  \
# Age of Household Head                                                           Age of Household Head
# Civil Status of Household Head                                         Civil Status of Household Head
# Community name                                                                         Community name
# Community name_Baixote                                                                  qquad Baixote
# Community name_Chita                                                                      qquad Chita
# Community name_Marajá                                                                    qquad Marajá
# Community name_Monte Sinai                                                          qquad Monte Sinai
# Community name_Nova Esperança                                                    qquad Nova Esperança
# Community name_Nova Sugar caneã                                                qquad Nova Sugar caneã
# Community name_Pagodão                                                                  qquad Pagodão
# Community name_Santa Isabel                                                        qquad Santa Isabel
# Community name_Santo Antônio                                                      qquad Santo Antônio
# Community name_São Tomé                                                                qquad São Tomé
# Community name_Terra Preta                                                          qquad Terra Preta
# Community name_Tiririca                                                                qquad Tiririca
# Community name_Três unitos                                                          qquad Três unitos
# Education of Household Head                                               Education of Household Head
# Gender of Household Head                                                     Gender of Household Head
# House Ownership                                                                       House Ownership
# Monthly Income of the Family                                             Monthly Income of the Family
# Normal Cooking Area                                                               Normal Cooking Area
# Number of Men in Household                                                 Number of Men in Household
# Number of Women in Household                                             Number of Women in Household
# Number of meals per day                                                       Number of meals per day
# Number of people at meals daily                                       Number of people at meals daily
# Number of people contributing to the monthly in...  Number of people contributing to the monthly i...
# Residence                                                                                   Residence
#
#                                                     weight_{G,C,F}  \
# Age of Household Head                                    -4.619220
# Civil Status of Household Head                            1.162254
# Community name                                                 NaN
# Community name_Baixote                                    0.969264
# Community name_Chita                                     13.222499
# Community name_Marajá                                    13.504829
# Community name_Monte Sinai                                9.956167
# Community name_Nova Esperança                            -0.219286
# Community name_Nova Sugar caneã                           4.528651
# Community name_Pagodão                                   -0.045175
# Community name_Santa Isabel                              23.256251
# Community name_Santo Antônio                              3.641945
# Community name_São Tomé                                  24.625012
# Community name_Terra Preta                                1.751577
# Community name_Tiririca                                  15.960117
# Community name_Três unitos                                1.806068
# Education of Household Head                              -2.244878
# Gender of Household Head                                 -1.242361
# House Ownership                                         -24.598965
# Monthly Income of the Family                             -5.075563
# Normal Cooking Area                                      -9.323084
# Number of Men in Household                               -4.766971
# Number of Women in Household                             -6.130529
# Number of meals per day                                   2.174695
# Number of people at meals daily                          22.508330
# Number of people contributing to the monthly in...        4.236916
# Residence                                               -12.657528
#
#                                                     pval_{G,C,F}  \
# Age of Household Head                                   0.023717
# Civil Status of Household Head                          0.292896
# Community name                                               NaN
# Community name_Baixote                                  0.589303
# Community name_Chita                                    0.960351
# Community name_Marajá                                   0.937191
# Community name_Monte Sinai                              0.924547
# Community name_Nova Esperança                           0.887989
# Community name_Nova Sugar caneã                         0.998635
# Community name_Pagodão                                  0.977006
# Community name_Santa Isabel                             0.999881
# Community name_Santo Antônio                            0.072397
# Community name_São Tomé                                 0.999690
# Community name_Terra Preta                              0.285914
# Community name_Tiririca                                 0.985697
# Community name_Três unitos                              0.349317
# Education of Household Head                             0.379449
# Gender of Household Head                                0.222715
# House Ownership                                         0.999877
# Monthly Income of the Family                            0.090042
# Normal Cooking Area                                     0.968555
# Number of Men in Household                              0.337121
# Number of Women in Household                            0.115519
# Number of meals per day                                 0.426737
# Number of people at meals daily                         0.095501
# Number of people contributing to the monthly in...      0.311567
# Residence                                               0.957208
#
#                                                     weight_{G,F}  pval_{G,F}  \
# Age of Household Head                                  -3.386651    0.133429
# Civil Status of Household Head                          1.649915    0.183498
# Community name                                               NaN         NaN
# Community name_Baixote                                  8.552948    0.879424
# Community name_Chita                                   19.820894    0.941883
# Community name_Marajá                                  22.289284    0.901669
# Community name_Monte Sinai                             18.839594    0.874494
# Community name_Nova Esperança                           6.778622    0.904290
# Community name_Nova Sugar caneã                        16.766535    0.994947
# Community name_Pagodão                                  9.339442    0.868394
# Community name_Santa Isabel                            -7.382829    1.000000
# Community name_Santo Antônio                           11.257951    0.841749
# Community name_São Tomé                                -7.875465    1.000000
# Community name_Terra Preta                              9.784993    0.862190
# Community name_Tiririca                               -13.107598    1.000000
# Community name_Três unitos                             11.016996    0.845055
# Education of Household Head                            -3.406284    0.201123
# Gender of Household Head                               -0.862858    0.453265
# House Ownership                                         0.481118    0.852599
# Monthly Income of the Family                            1.486227    0.599860
# Normal Cooking Area                                   -10.845326    0.963425
# Number of Men in Household                             -5.312839    0.298972
# Number of Women in Household                           -7.788979    0.069035
# Number of meals per day                                 3.441667    0.238143
# Number of people at meals daily                        28.885913    0.036423
# Number of people contributing to the monthly in...      4.590322    0.288693
# Residence                                             -11.536068    0.960997
#
#                                                     weight_{G}  pval_{G}
# Age of Household Head                                -2.953299  0.153426
# Civil Status of Household Head                        1.964613  0.090317
# Community name                                             NaN       NaN
# Community name_Baixote                               -0.456938  0.801879
# Community name_Chita                                 10.109015  0.969682
# Community name_Marajá                                13.025750  0.939414
# Community name_Monte Sinai                            9.811392  0.925640
# Community name_Nova Esperança                        -0.760155  0.635875
# Community name_Nova Sugar caneã                       5.673387  0.998290
# Community name_Pagodão                               -1.264585  0.456192
# Community name_Santa Isabel                          -8.918697  0.999999
# Community name_Santo Antônio                          1.269677  0.538653
# Community name_São Tomé                              -8.418131  0.999999
# Community name_Terra Preta                           -0.150355  0.934934
# Community name_Tiririca                              14.539507  0.986970
# Community name_Três unitos                            1.112148  0.556840
# Education of Household Head                          -0.935312  0.715788
# Gender of Household Head                             -0.812542  0.429123
# House Ownership                                       1.660881  0.476203
# Monthly Income of the Family                         -1.428691  0.573171
# Normal Cooking Area                                  15.866468  0.999970
# Number of Men in Household                           -6.183432  0.236448
# Number of Women in Household                         -6.614422  0.120548
# Number of meals per day                               2.625428  0.346022
# Number of people at meals daily                      22.028540  0.116644
# Number of people contributing to the monthly in...    1.479929  0.741942
# Residence                                           -11.998912  0.959432
